# %% [markdown]
# <a href="https://colab.research.google.com/github/DanendraPassadhi/PCVK/blob/main/PCVK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Langkah 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# # Langkah 2

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
"https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
"https://scontent.fsub8-2.fna.fbcdn.net/v/t39.30808-6/494569844_701448855914482_1340474526443337104_n.jpg?stp=dst-jpg_p526x296_tt6&_nc_cat=109&ccb=1-7&_nc_sid=aa7b47&_nc_eui2=AeEF0CWxTi5NQ7AbRwSMZtbTmkUCTZIdkcKaRQJNkh2RwnSyvoD07sWVvQpk8bSXezKYWolZop67F3tkrsQMzIx0&_nc_ohc=qaGaEwCnX7YQ7kNvwF3VlYR&_nc_oc=AdmRaSr08iKL-lUmLsJfykty9mXGugj3Y26rqsTp-KFbPqqEFq17E8GFAIfuM6sADHQ&_nc_zt=23&_nc_ht=scontent.fsub8-2.fna&_nc_gid=c_Cxd4hHIUXa228Xt9HedQ&oh=00_AfUNvI2eBTrQRL6PWlQwCy9HCzCmVLs_1rXEfNOyrSucHA&oe=68B1F3ED"]
"https://i.pinimg.com/736x/6d/06/4d/6d064d52f370e11fe2d4029718686293.jpg"
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print("\n")
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=526x394>

# %% [markdown]
# # Langkah 3

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, "x", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  394 x 263
# <PIL.Image.Image image mode=RGB size=263x394>

# %% [markdown]
# # Langkah 4

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=526x394>

# %% [markdown]
# # PRAKTIKUM

# %% [markdown]
# ## Garis Vertikal

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis horizontal ditengah image
for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=526x394>

# %% [markdown]
# ## Garis Menyilang

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for i in range(tinggi):
    for j in range(lebar):

        # diagonal 1
        if abs(j * tinggi - i * lebar) < max(tinggi, lebar):
            image_3[i, j] = [255, 255, 255]

        # diagonal 2
        if abs((lebar-1-j) * tinggi - i * lebar) < max(tinggi, lebar):
            image_3[i, j] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=526x394>

# %% [markdown]
# ## Garis Horizontal dengan Panjang Tertentu

# %%
image = io.imread("https://c4.wallpaperflare.com/wallpaper/156/382/461/kitten-desktop-backgrounds-wallpaper-preview.jpg")
image = cv.resize(image, (0,0), fx=0.5, fy=0.5)

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (90):
  image_3[120, y+100] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=728x242>

# %% [markdown]
# ## Kotak Menggunakan Kumpulan Piksel

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

sisi = 80
for x in range (sisi):
  for y in range (sisi):
    image_3[85+x, 100+y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=728x242>
